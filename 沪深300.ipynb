# %%
far = analyze_factor(factor=MlFactor,
                     # 最大内存使用到1.4G
                     start_date='2014-01-01',
                     end_date='2019-12-27',
                     weight_method='avg',
                     universe='000300.XSHG',
                     industry='jq_l1',
                     quantiles=10,
                     periods=(3, 5, 10)
                    )

# %%
far.plot_returns_table(demeaned=True, group_adjust=False)
# Out:
# 收益分析
#                                                period_3    ...      period_10
# Ann. alpha                                        0.156    ...          0.127
# beta                                              0.020    ...         -0.015
# Mean Period Wise Return Top Quantile (bps)        4.978    ...          4.498
# Mean Period Wise Return Bottom Quantile (bps)    -8.077    ...         -6.131
# Mean Period Wise Spread (bps)                    13.268    ...         10.758
#
# [5 rows x 3 columns]

# %%
far.plot_returns_table(demeaned=True, group_adjust=True)
# Out:
# 收益分析
#                                                period_3    ...      period_10
# Ann. alpha                                        0.156    ...          0.127
# beta                                              0.020    ...         -0.015
# Mean Period Wise Return Top Quantile (bps)        4.648    ...          4.143
# Mean Period Wise Return Bottom Quantile (bps)    -7.777    ...         -6.066
# Mean Period Wise Spread (bps)                    12.606    ...         10.310
#
# [5 rows x 3 columns]

# %%
far.plot_quantile_returns_bar(by_group=False, demeaned=True, group_adjust=False)

# %%
far.plot_cumulative_returns_by_quantile(period=(3, 5), demeaned=True, group_adjust=True)

# %%
far.plot_ic_by_group(group_adjust=True, method='rank')

# %%
far.plot_quantile_average_cumulative_return(periods_before=5, periods_after=30, 
                                            by_quantile=False, std_bar=False, demeaned=True, group_adjust=True)
